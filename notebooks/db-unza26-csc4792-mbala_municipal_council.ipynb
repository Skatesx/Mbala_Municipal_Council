# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

# %%
df=pd.read_csv data./db-unza26-csc4792-mbala_municipal_council_pages.csv
# Out:
#   Cell In[3], line 1
#     df=pd.read_csv data./db-unza26-csc4792-mbala_municipal_council_pages.csv
#                    ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv "data./db-unza26-csc4792-mbala_municipal_council_pages.csv"
# Out:
#   Cell In[4], line 1
#     df=pd.read_csv "data./db-unza26-csc4792-mbala_municipal_council_pages.csv"
#                    ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("data./db-unza26-csc4792-mbala_municipal_council_pages.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("data./db-unza26-csc4792-mbala_municipal_council_pages.csv")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df = pd.read_csv("data/db-unza26-csc4792-mbala_municipal_council_pages.csv
# Out:
#   Cell In[6], line 1
#     df = pd.read_csv("data/db-unza26-csc4792-mbala_municipal_council_pages.csv
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df = pd.read_csv("data/db-unza26-csc4792-mbala_municipal_council_pages.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_csv("data/db-unza26-csc4792-mbala_municipal_council_pages.csv")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df = pd.read_csv("data/.db-unza26-csc4792-mbala_municipal_council_pages.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv("data/.db-unza26-csc4792-mbala_municipal_council_pages.csv")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\admin\OneDrive\Documents\CSC4792_17_Mbala_Munincipal_Council

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'documents',
#  'figures',
#  'notebooks',
#  'README.md',
#  'Untitled.ipynb']

# %%
os.listdir("data")
# Out:
# ['raw']

# %%
os.listdir("data/raw")
# Out:
# ['db-unza26-csc4792-mbala_municipal_council_pages.csv']

# %%
df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv", sep=None, engine"python")
# Out:
#   Cell In[14], line 1
#     df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv", sep=None, engine"python")
#                                                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv", sep=None, engine="python")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_csv("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv", sep=None, engine="python")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import csv

with open("data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv", "r", encoding="utf-8") as f:
    for i in range(5):
        print(i + 1, repr(f.readline()))
# Out:
# 1 'url|page_id|post_id|title|date|topics|text_content|text_length_chars\n'
# 2 'https://www.mbalacouncil.gov.zm/?page_id=3645|3645||Public Notices – Mbala Municipal Council||budget_finance;notice|Public Notices – Mbala Municipal Council Menu Contact Information Mbala Municipal Council Mbala District Northern Province, Zambia A.K Wilombe Lane P.O Box 420057 Tel: 0971921116 Email:mbalacouncil@gmail.com Quick Links Ministry of Local Government and Rural Development Local Government Service Comission Ministry of Finance and National PlanningMinistry of Finance and National Planning Ministry of Agriculture National Assembly of Zambia Local Government Training Institute SMART Zambia ©2025. SMART Zambia Institute & Mbala Municipal Council. All Rights Reserved.|567\n'
# ...

# %%
df = pd.read_csv(
    "data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv",
    sep="|"
)

# %%
df.head()
# Out:
#                                              url  page_id  post_id  \
# 0  https://www.mbalacouncil.gov.zm/?page_id=3645   3645.0      NaN
# 1  https://www.mbalacouncil.gov.zm/?page_id=3914   3914.0      NaN
# 2  https://www.mbalacouncil.gov.zm/?page_id=2104   2104.0      NaN
# 3        https://www.mbalacouncil.gov.zm/?p=4208      NaN   4208.0
# 4  https://www.mbalacouncil.gov.zm/?page_id=3932   3932.0      NaN
#
#                                                title  \
# 0           Public Notices – Mbala Municipal Council
# 1          Dept Of Finance – Mbala Municipal Council
# 2        Application Forms – Mbala Municipal Council
# 3  MBALA CBD GETS FACELIFT THROUGH THE PRESIDENT ...
# 4      Dept of Agriculture – Mbala Municipal Council
#
#                         date                     topics  \
# 0                        NaN      budget_finance;notice
# 1                        NaN  budget_finance;department
# 2                        NaN         cdf;budget_finance
# ...

# %%
df.columns
# Out:
# Index(['url', 'page_id', 'post_id', 'title', 'date', 'topics', 'text_content',
#        'text_length_chars'],
#       dtype='str')

# %%
df.shape
# Out:
# (42, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   url                42 non-null     str
#  1   page_id            18 non-null     float64
#  2   post_id            22 non-null     float64
#  3   title              42 non-null     str
#  4   date               28 non-null     str
#  5   topics             42 non-null     str
#  6   text_content       42 non-null     str
#  7   text_length_chars  42 non-null     int64
# dtypes: float64(2), int64(1), str(5)
# memory usage: 2.8 KB

# %%
df.isnull().sum()
# Out:
# url                   0
# page_id              24
# post_id              20
# title                 0
# date                 14
# topics                0
# text_content          0
# text_length_chars     0
# dtype: int64

# %%
df[["page_id", "post_id", "title", "date"]].head(10)
# Out:
#    page_id  post_id                                              title  \
# 0   3645.0      NaN           Public Notices – Mbala Municipal Council
# 1   3914.0      NaN          Dept Of Finance – Mbala Municipal Council
# 2   2104.0      NaN        Application Forms – Mbala Municipal Council
# 3      NaN   4208.0  MBALA CBD GETS FACELIFT THROUGH THE PRESIDENT ...
# 4   3932.0      NaN      Dept of Agriculture – Mbala Municipal Council
# 5   3930.0      NaN  Dept of Fisheries, Livestock and Veterinary Se...
# 6   3647.0      NaN                    Forms – Mbala Municipal Council
# 7   3920.0      NaN  Dept of Engineering Services – Mbala Municipal...
# 8   3928.0      NaN  Dept of Housing and Social Services – Mbala Mu...
# 9      NaN   4156.0       CDF WATER BOWSER DELIVERED TO MBALA DISTRICT
#
#                         date
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  2026-09-08T08:54:02+00:00
# 4                        NaN
# ...

# %%
df[["page_id", "post_id"]].notna().sum()
# Out:
# page_id    18
# post_id    22
# dtype: int64

# %%
df[df["page_id"].isna() & df["post_id"].isna()][["url", "title", "date", "topics"]]
# Out:
#                                  url                            title  \
# 20   https://www.mbalacouncil.gov.zm  Mbala Municipal Council – Mbala
# 22  https://www.mbalacouncil.gov.zm/  Mbala Municipal Council – Mbala
#
#            date topics
# 20  24 and 2025    cdf
# 22  24 and 2025    cdf

# %%
df.duplicate().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.duplicate().sum()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df["page_id"].isna() & df["post_id"].isna()].T
# Out:
#                                                                   20  \
# url                                  https://www.mbalacouncil.gov.zm
# page_id                                                          NaN
# post_id                                                          NaN
# title                                Mbala Municipal Council – Mbala
# date                                                     24 and 2025
# topics                                                           cdf
# text_content       CDF UPGRADES MBULU MARKET WITH A MODERN MARKET...
# text_length_chars                                                221
#
#                                                                   22
# url                                 https://www.mbalacouncil.gov.zm/
# page_id                                                          NaN
# post_id                                                          NaN
# title                                Mbala Municipal Council – Mbala
# ...

# %%
df = df.drop(index=[22])

# %%
df.shape
# Out:
# (41, 8)

# %%
df["date"] = pd.to_datetime(df["date"], errors="coerce")

# %%
df["date"].isna().sum()
# Out:
# np.int64(19)

# %%
df[df["date"].isna()][["title", "url"]]
# Out:
#                                                 title  \
# 0            Public Notices – Mbala Municipal Council
# 1           Dept Of Finance – Mbala Municipal Council
# 2         Application Forms – Mbala Municipal Council
# 4       Dept of Agriculture – Mbala Municipal Council
# 5   Dept of Fisheries, Livestock and Veterinary Se...
# 6                     Forms – Mbala Municipal Council
# 7   Dept of Engineering Services – Mbala Municipal...
# 8   Dept of Housing and Social Services – Mbala Mu...
# 10           ZDSP Documents – Mbala Municipal Council
# 11                  Mandate – Mbala Municipal Council
# 12               Who we are – Mbala Municipal Council
# 13  Dept of Human Resource and Administration – Mb...
# 15             News Updates – Mbala Municipal Council
# 16  Investment Opportunities – Mbala Municipal Cou...
# 17        E-Services Portal – Mbala Municipal Council
# 18  CDF Projects Implemented – Mbala Municipal Cou...
# ...

# %%
df.isnull().sum()
# Out:
# url                   0
# page_id              23
# post_id              19
# title                 0
# date                 19
# topics                0
# text_content          0
# text_length_chars     0
# dtype: int64

# %%
df["record_type"] = df.apply(
    lambda row: "page" if pd.notna(row["page_id"])
    else ("post" if pd.notna(row["post_id"]) else "unclassified"),
    axis=1
)

# %%
df["record_type"].value_counts()
# Out:
# record_type
# post            22
# page            18
# unclassified     1
# Name: count, dtype: int64

# %%
df["record_type"] = df.apply(
    lambda row: "page" if pd.notna(row["page_id"])
    else ("post" if pd.notna(row["post_id"]) else "unclassified"),
    axis=1
)

# %%
df[df["record_type"] == "unclassified"][["url", "title", "date", "topics", "text_content"]]
# Out:
#                                 url                            title date  \
# 20  https://www.mbalacouncil.gov.zm  Mbala Municipal Council – Mbala  NaT
#
#    topics                                       text_content
# 20    cdf  CDF UPGRADES MBULU MARKET WITH A MODERN MARKET...

# %%
text_columns = ["url", "title", "topics", "text_content"]

for col in text_columns:
    df[col] = df[col].astype(str).str.strip()

# %%
df.head()
# Out:
#                                              url  page_id  post_id  \
# 0  https://www.mbalacouncil.gov.zm/?page_id=3645   3645.0      NaN
# 1  https://www.mbalacouncil.gov.zm/?page_id=3914   3914.0      NaN
# 2  https://www.mbalacouncil.gov.zm/?page_id=2104   2104.0      NaN
# 3        https://www.mbalacouncil.gov.zm/?p=4208      NaN   4208.0
# 4  https://www.mbalacouncil.gov.zm/?page_id=3932   3932.0      NaN
#
#                                                title  \
# 0           Public Notices – Mbala Municipal Council
# 1          Dept Of Finance – Mbala Municipal Council
# 2        Application Forms – Mbala Municipal Council
# 3  MBALA CBD GETS FACELIFT THROUGH THE PRESIDENT ...
# 4      Dept of Agriculture – Mbala Municipal Council
#
#                        date                     topics  \
# 0                       NaT      budget_finance;notice
# 1                       NaT  budget_finance;department
# 2                       NaT         cdf;budget_finance
# ...

# %%
df["date_original"] = df["date"]

# %%
df_raw = pd.read_csv(
    "data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv",
    sep="|"
)

# %%
df_raw["date"].head(10)
# Out:
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3    2026-09-08T08:54:02+00:00
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9    2026-09-08T07:23:23+00:00
# Name: date, dtype: str

# %%
df["date"] = df_raw.loc[df.index, "date"]

# %%
df["date'].head(10)
# Out:
#   Cell In[45], line 1
#     df["date'].head(10)
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df["date"].head(10)
# Out:
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3    2026-09-08T08:54:02+00:00
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9    2026-09-08T07:23:23+00:00
# Name: date, dtype: str

# %%
df.dtypes
# Out:
# url                                  str
# page_id                          float64
# post_id                          float64
# title                                str
# date                                 str
# topics                               str
# text_content                         str
# text_length_chars                  int64
# record_type                          str
# date_original        datetime64[us, UTC]
# dtype: object

# %%
df["page_id"] = df["page_id"].astype("Int64")
df["post_id"] = df["post_id"].astype("Int64")

# %%
df = df.drop(columns=["date_original"])

# %%
df.dtypes
# Out:
# url                    str
# page_id              Int64
# post_id              Int64
# title                  str
# date                   str
# topics                 str
# text_content           str
# text_length_chars    int64
# record_type            str
# dtype: object

# %%
df[["title", "topics", "text_content"]].isna().sum()
# Out:
# title           0
# topics          0
# text_content    0
# dtype: int64

# %%
(df["text_content"].str.strip() == "").sum()
# Out:
# np.int64(0)

# %%
df["calculated_text_length"] = df["text_content"].str.len()

# %%
(df["text_length_chars"] != df["calculated_text_length"]).sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=["calculated_text_length"])

# %%
df.shape
# Out:
# (41, 9)

# %%
df.columns.tolist()
# Out:
# ['url',
#  'page_id',
#  'post_id',
#  'title',
#  'date',
#  'topics',
#  'text_content',
#  'text_length_chars',
#  'record_type']

# %%
df[['title', 'topics', 'text_content']].isna().sum()
# Out:
# title           0
# topics          0
# text_content    0
# dtype: int64

# %%
df[['title', 'topics', 'text_content']].apply(lambda col: (col == '').sum())
# Out:
# title           0
# topics          0
# text_content    0
# dtype: int64

# %%
df.to_csv('mbala_municipal_council_pages.csv', index=False)

# %%
import os
os.path.exists('mbala_municipal_council_pages.csv')
# Out:
# True

# %%
df.to_csv("data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv",sep="|",index=False)

# %%
import os os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")
# Out:
#   Cell In[63], line 1
#     import os os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")
#               ^
# SyntaxError: invalid syntax

# %%
import os os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")

# %%
import os os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")
# Out:
#   Cell In[2], line 1
#     import os os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")
#               ^
# SyntaxError: invalid syntax

# %%
import os 
os.path.exists("data/db-unza-csc4792-mbala_municipal_council_cleaned.csv")
# Out:
# False

# %%
import os
os.path.exists("data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv")
# Out:
# False

# %%
os.listdir("data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.listdir("data")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\OneDrive\\Documents\\CSC4792_17_Mbala_Munincipal_Council\\notebooks'

# %%
df.to_csv(
    "../data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv",
    sep="|",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.to_csv(
#       2     "../data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv",
#       3     sep="|",
#       4     index=False
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv",
    sep="|"
)

df.shape
# Out:
# (42, 8)

# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/db-unza26-csc4792-mbala_municipal_council_pages.csv",
    sep="|"
)

print(df.shape)
# Out:
# (42, 8)

# %%
df.head()
# Out:
#                                              url  page_id  post_id  \
# 0  https://www.mbalacouncil.gov.zm/?page_id=3645   3645.0      NaN
# 1  https://www.mbalacouncil.gov.zm/?page_id=3914   3914.0      NaN
# 2  https://www.mbalacouncil.gov.zm/?page_id=2104   2104.0      NaN
# 3        https://www.mbalacouncil.gov.zm/?p=4208      NaN   4208.0
# 4  https://www.mbalacouncil.gov.zm/?page_id=3932   3932.0      NaN
#
#                                                title  \
# 0           Public Notices – Mbala Municipal Council
# 1          Dept Of Finance – Mbala Municipal Council
# 2        Application Forms – Mbala Municipal Council
# 3  MBALA CBD GETS FACELIFT THROUGH THE PRESIDENT ...
# 4      Dept of Agriculture – Mbala Municipal Council
#
#                         date                     topics  \
# 0                        NaN      budget_finance;notice
# 1                        NaN  budget_finance;department
# 2                        NaN         cdf;budget_finance
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (42, 8)

# %%
df["record_type"] = df.apply(
    lambda row: "page" if pd.notna(row["page_id"])
    else ("post" if pd.notna(row["post_id"]) else "unclassified"),
    axis=1
)

# %%
df["record_type"].value_counts()
# Out:
# record_type
# post            22
# page            18
# unclassified     2
# Name: count, dtype: int64

# %%
df[df["page_id"].isna() & df["post_id"].isna()][
    ["url", "title", "date", "topics", "text_content"]
]
# Out:
#                                  url                            title  \
# 20   https://www.mbalacouncil.gov.zm  Mbala Municipal Council – Mbala
# 22  https://www.mbalacouncil.gov.zm/  Mbala Municipal Council – Mbala
#
#            date topics                                       text_content
# 20  24 and 2025    cdf  CDF UPGRADES MBULU MARKET WITH A MODERN MARKET...
# 22  24 and 2025    cdf  CDF UPGRADES MBULU MARKET WITH A MODERN MARKET...

# %%
df = df.drop(index=22).reset_index(drop=True)

# %%
df.shape
# Out:
# (41, 9)

# %%
df.to_csv(
    "../data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv",
    sep="|",
    index=False
)

# %%
import os

print(os.path.exists(
    "../data/db-unza26-csc4792-mbala_municipal_council_cleaned.csv"
))
# Out:
# True

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (41, 9)
# ['url', 'page_id', 'post_id', 'title', 'date', 'topics', 'text_content', 'text_length_chars', 'record_type']

# %%
import pandas as pd

extra = pd.read_csv(
    "../mbala_municipal_council_pages.csv",
    sep="|"
)

print(extra.shape)
print(extra.columns.tolist())
# Out:
# (41, 1)
# ['url,page_id,post_id,title,date,topics,text_content,text_length_chars,record_type']

# %%
with open("../mbala_municipal_council_pages.csv", "r", encoding="utf-8") as f:
    for i in range(3):
        print(repr(f.readline()))
# Out:
# 'url,page_id,post_id,title,date,topics,text_content,text_length_chars,record_type\n'
# 'https://www.mbalacouncil.gov.zm/?page_id=3645,3645,,Public Notices – Mbala Municipal Council,,budget_finance;notice,"Public Notices – Mbala Municipal Council Menu Contact Information Mbala Municipal Council Mbala District Northern Province, Zambia A.K Wilombe Lane P.O Box 420057 Tel: 0971921116 Email:mbalacouncil@gmail.com Quick Links Ministry of Local Government and Rural Development Local Government Service Comission Ministry of Finance and National PlanningMinistry of Finance and National Planning Ministry of Agriculture National Assembly of Zambia Local Government Training Institute SMART Zambia ©2025. SMART Zambia Institute & Mbala Municipal Council. All Rights Reserved.",567,page\n'
# ...
